# %%
from keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype('float32') / 255
test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype('float32') / 255

# %%
from keras import models
from keras import layers

# %%
network = models.Sequential()
network.add(layers.Dense(512, activation='relu', input_shape=(28 * 28,)))
network.add(layers.Dense(10, activation='softmax'))

# %%
network.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

# %%
from keras.utils import to_categorical

train_labels = to_categorical(train_labels)#標籤類別化
test_labels = to_categorical(test_labels)

# %%
network.fit(train_images, train_labels, epochs=5, batch_size=128)
# Out:
# Epoch 1/5
# 469/469 [==============================] - 5s 10ms/step - loss: 0.2640 - accuracy: 0.9235
# Epoch 2/5
# 469/469 [==============================] - 6s 13ms/step - loss: 0.1087 - accuracy: 0.9677
# Epoch 3/5
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0703 - accuracy: 0.9789
# Epoch 4/5
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0522 - accuracy: 0.9840
# Epoch 5/5
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0384 - accuracy: 0.9885

# %%
from keras import layers
layer = layers.Dense(32, input_shape=(784,))

# %%
from keras import models
from keras import layers

model = models.Sequential()
model.add(layers.Dense(32, input_shape=(784,)))
model.add(layers.Dense(32))

# %%
from keras import models
from keras import layers

model = models.Sequential()
model.add(layers.Dense(32, activation='relu', input_shape=(784,)))
model.add(layers.Dense(10, activation='softmax'))

# %%
input_tensor = layers.Input(shape=(784,))
x = layers.Dense(32, activation='relu')(input_tensor)
output_tensor = layers.Dense(10, activation='softmax')(x)

model = models.Model(inputs=input_tensor, outputs=output_tensor)

# %%
from keras import optimizers

model.compile(optimizer=optimizers.RMSprop(lr=0.001),
              loss='mse',
            metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/rmsprop.py:143: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
model.fit(train_images, train_labels, batch_size=128, epochs=10)
# Out:
# Epoch 1/10
# 469/469 [==============================] - 3s 4ms/step - loss: 0.0203 - accuracy: 0.8742
# Epoch 2/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0109 - accuracy: 0.9315
# Epoch 3/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0091 - accuracy: 0.9432
# Epoch 4/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0080 - accuracy: 0.9500
# Epoch 5/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0072 - accuracy: 0.9551
# Epoch 6/10
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0065 - accuracy: 0.9594
# Epoch 7/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0060 - accuracy: 0.9621
# Epoch 8/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0056 - accuracy: 0.9660
# Epoch 9/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0053 - accuracy: 0.9675
# Epoch 10/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0049 - accuracy: 0.9704
